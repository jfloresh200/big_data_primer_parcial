# %% [markdown]
# Caso real = Uso de netflix
#
# 1. que datos genera
#
# los datos se generan durante el uso de la pltaforma
#
# ¿ que datos genera ?
#
# #series y peliculas
# #Tiempo de reproduccion
# #calificaciones de usuarios

# %% [markdown]
# 2. ¿Quienes lo usan ?
#
# 1.La empresa de netflix
# 2.Analistas de datos
# 3.Ingenieros de software

# %% [markdown]
# 3. ¿Que problema resuelve ?
# 1.Recomendar peliculas y series personalizadas
# 2.Mejorar la experiencia de los usuarios
# 3.Detectar peliculas populares

# %% [markdown]
# 4. ¿Por qué no bastaría el Excel?
# seria muy complejo para excel por la variedad de datos y los datos se generan en tiempo real demaciados generando demaciados datos para que excel
